# %%
import pandas as pd

# Load each dataset
fake_df = pd.read_csv("News _dataset/Fake.csv")
true_df = pd.read_csv("News _dataset/True.csv")

# Add labels
fake_df["label"] = "FAKE"
true_df["label"] = "REAL"

# Combine into one dataframe
df = pd.concat([fake_df, true_df], ignore_index=True)

# Shuffle the rows
df = df.sample(frac=1).reset_index(drop=True)

# Save the combined dataframe to a new CSV file
df.to_csv("combined_news_data.csv", index=False)

# Display the first few rows of the dataframe
print(df.head())

print(df.info())

# Display the distribution of labels
print(df['label'].value_counts())
# Out:
#                                                title  \
# 0  Little prospect of Syria peace progress seen i...
# 1  Texas House passes 'bathroom bill' targeting p...
# 2  British PM May vows to stay as party plotters ...
# 3  South Africa's Dlamini-Zuma, ANC leadership co...
# 4  Colombia seizes 12 tons of cocaine, its bigges...
#
#                                                 text       subject  \
# 0  BEIRUT (Reuters) - A breakthrough in U.N.-back...     worldnews
# 1   (This version of the May 22 story was correct...  politicsNews
# 2  LONDON (Reuters) - British Prime Minister Ther...     worldnews
# 3  JOHANNESBURG (Reuters) - South African veteran...     worldnews
# 4  BOGOTA (Reuters) - Police seized more than 12 ...     worldnews
#
#                  date label
# 0  November 27, 2017   REAL
# 1       May 22, 2017   REAL
# 2    October 6, 2017   REAL
# 3  September 8, 2017   REAL
# 4   November 9, 2017   REAL
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  object
# dtypes: object(5)
# memory usage: 1.7+ MB
# None
# label
# FAKE    23481
# REAL    21417
# Name: count, dtype: int64
